# %% [markdown]
# This is an example for a notebook to be used with the random matrix class.
#
# It contains a first simple analysis of the signs of the eigenvalues of inverse distance matrices and compares these signs for various distributions.

# %%
# Import of the libraries. The notebook is numpy. For GPU systems the calculation 
# in RandomMatrix can be done with cupy and cupy is imported automatically if available.

import numpy as np
import RandomMatrix as rm
import matplotlib.pyplot as plt

# %% [markdown]
# General setup for a simulation with varying n_values

# %%
# create png flag for saving figures
create_png = False

# the number of targets
n_values = [2, 4, 8, 16, 32, 64, 80, 100, 150, 200]
n_values_np = np.array(n_values)

# the distribution of the targets
# 'normal' for normal distribution, 'uniform' for uniform distribution
distribution = 'uniform' # 'normal', 'uniform', 'cube', 'sphere', 'circle', 'student_t'

# which space dimension to use, totally experimental
space_dimension = 3

# 'correlated' for correlated matrices, 'uncorrelated' for uncorrelated matrices
# Note: Uncorrelated matrices are not yet supported in the MatrixInverseDistance3D class
correlated = True # True or False

# use a different exponent
exponent = -1 # -1 for inverse distance, -2 for inverse square distance, etc.
logarithmic = False # use logarithmic scaling in this case exponent is ignored
logscale = 0.05 # the scale of the logarithmic distribution

# hardcore is the minimum distance between targets
hardcore = 0.001 # minimum distance between targets, 0.0 means no hardcore

# is the ensemble length scale changed with N^(1/3) to keep the density constant?
scaled = False

# the goe spacing range for eigenvalue spacing analysis
goe_spacing_range = 2

# the sample size of the first simulation
sample_size_first = 400
sample_strategy = 'homogenous' # 'homogenous', 'nsqrt' or 'n'

# generate the sample sizes for each n
sample_values = []
for n in n_values:
    if sample_strategy == 'homogenous':
        sample_value = sample_size_first
    elif sample_strategy == 'nsqrt':
        sample_value = sample_size_first * np.sqrt( n_values[0] / n )
    elif sample_strategy == 'n':
        sample_value = sample_size_first * ( n_values[0] / n ) 
    else:
        raise ValueError("Unknown sample strategy: {}".format(sample_strategy))
    if sample_value < 1:
        sample_value = 1
    else:
        sample_value = int(sample_value)
    sample_values.append(sample_value)
    
print("N values:", n_values)
print("Sample values:", sample_values)

matrices = []
simulations = []
for n in n_values:
    #if correlated:
        # Create a correlated matrix using the MatrixInverseDistance3D class
        # Note: This class is designed for 3D distributions, so we use it for correlated matrices
    G = rm.MatrixInverseDistance(n, distribution=distribution, 
                                        scaled=scaled, 
                                        exponent=exponent,
                                        logarithmic=logarithmic, 
                                        logscale=logscale,
                                        hardcore=hardcore,
                                        dimension=space_dimension,
                                        correlated=correlated)
    #else:
        # Create an uncorrelated matrix using the MatrixUncorrelated class, only 
        # limited support for distributions
        # G = rm.MatrixUncorrelated(n, scaled=scaled)
    matrices.append(G)
    S = rm.Simulation(G)
    simulations.append(S)
# Out:
# N values: [2, 4, 8, 16, 32, 64, 80, 100, 150, 200]
# Sample values: [400, 400, 400, 400, 400, 400, 400, 400, 400, 400]
# MatrixInverseDistance initialized with parameters:
# N: 2, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3
# MatrixInverseDistance initialized with parameters:
# N: 4, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3
# MatrixInverseDistance initialized with parameters:
# N: 8, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3
# MatrixInverseDistance initialized with parameters:
# N: 16, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3
# MatrixInverseDistance initialized with parameters:
# N: 32, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3
# MatrixInverseDistance initialized with parameters:
# N: 64, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3
# MatrixInverseDistance initialized with parameters:
# N: 80, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3
# MatrixInverseDistance initialized with parameters:
# N: 100, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3
# MatrixInverseDistance initialized with parameters:
# N: 150, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3
# MatrixInverseDistance initialized with parameters:
# N: 200, scaled: False, distribution: uniform, hardcore: 0.001, solver: numpy, correlated: True, exponent: -1, logarithmic: False, logscale: (0.05,), space_dimension: 3

# %% [markdown]
# Simulation - Runtime on MacBook Pro 11 minutes

# %%
for S in simulations:
    S.random_seed(42)
    sample_size = sample_values[simulations.index(S)]
    print("n =", S.Matrix.N, "Sample size =", sample_size, "Randomness:", 3*S.Matrix.N*sample_size)
    S.sample(sample_size)
    print("Finished with hardcore count:", S.Matrix.hardcore_count, ", element average:", S.element_average)
# Out:
# n = 2 Sample size = 400 Randomness: 2400
# Finished with hardcore count: 0.0 , element average: 1.1513577350781288
# n = 4 Sample size = 400 Randomness: 4800
# Finished with hardcore count: 0.0 , element average: 1.161401073383293
# n = 8 Sample size = 400 Randomness: 9600
# Finished with hardcore count: 0.0 , element average: 1.2078873477624652
# n = 16 Sample size = 400 Randomness: 19200
# Finished with hardcore count: 0.0 , element average: 1.204893606993385
# n = 32 Sample size = 400 Randomness: 38400
# Finished with hardcore count: 0.0 , element average: 1.1996169870644013
# n = 64 Sample size = 400 Randomness: 76800
# Finished with hardcore count: 0.0 , element average: 1.2008175497149722
# n = 80 Sample size = 400 Randomness: 96000
# Finished with hardcore count: 0.0 , element average: 1.2008457970690334
# n = 100 Sample size = 400 Randomness: 120000
# Finished with hardcore count: 0.0 , element average: 1.1985374338974832
# n = 150 Sample size = 400 Randomness: 180000
# Finished with hardcore count: 0.0 , element average: 1.200362667557644
# n = 200 Sample size = 400 Randomness: 240000
# Finished with hardcore count: 0.0 , element average: 1.1978741733589517

# %%
for S in simulations:
    S.print_results()
# Out:
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 2 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.1513577350781288 std: 0.6234055786767282
# Inverse of element average: 0.8685397852754618
# Average maximum row sum: 5.392396035223265 std: 0.6234055786767281
# Average row sum: 1.1513577350781288 std: 0.6234055786767282
# Average minimum row sum: 0.5315433034041676 std: 0.6234055786767281
# Average nearest neighbor distance: 1.0384786985245376 std: 0.37012056598657694
# Inverse of average nearest neighbor distance: 0.9629470507395022
# Average of inverse nearest neighbor distance: 1.1513577350781288 std: 0.6234055786767281
# Average smallest distance in matrix: 1.0384786985245376 std: 0.37012056598657694
# ----------------------- Spectrum ------------------------
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 4 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.161401073383293 std: 0.7282732848693478
# Inverse of element average: 0.861028995854883
# Average maximum row sum: 15.226323577504441 std: 1.4796429730489145
# Average row sum: 3.4842032201498787 std: 1.261406331188793
# Average minimum row sum: 1.737351841346666 std: 0.5948616579516016
# Average nearest neighbor distance: 0.7357734804149877 std: 0.1752568236317836
# Inverse of average nearest neighbor distance: 1.3591139482711234
# Average of inverse nearest neighbor distance: 1.4601306987903333 std: 0.4872296410850597
# Average smallest distance in matrix: 0.5715295662023396 std: 0.20513183430128346
# ----------------------- Spectrum ------------------------
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 8 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.2078873477624652 std: 0.9141223127589796
# Inverse of element average: 0.8278917747192539
# Average maximum row sum: 46.242918649960735 std: 3.322825370130994
# Average row sum: 8.455211434337256 std: 2.4185403074554657
# Average minimum row sum: 4.287384806728412 std: 0.797269558445859
# Average nearest neighbor distance: 0.5300489762149369 std: 0.09324420856789349
# Inverse of average nearest neighbor distance: 1.8866181143126974
# Average of inverse nearest neighbor distance: 1.9507338698762025 std: 0.3777129108426232
# Average smallest distance in matrix: 0.3160678235537508 std: 0.11962156801677264
# ----------------------- Spectrum ------------------------
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 16 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.204893606993385 std: 0.8838640947596011
# Inverse of element average: 0.8299487973011463
# Average maximum row sum: 57.37793955563994 std: 4.764632109376051
# Average row sum: 18.073404104900778 std: 3.4231909193146293
# Average minimum row sum: 10.383932039905918 std: 0.9924880456449711
# Average nearest neighbor distance: 0.40146014950883196 std: 0.04683453650315735
# Inverse of average nearest neighbor distance: 2.4909072574786166
# Average of inverse nearest neighbor distance: 2.5270085020568644 std: 0.31455630739096846
# Average smallest distance in matrix: 0.18510519466464978 std: 0.06834420090187668
# ----------------------- Spectrum ------------------------
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 32 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.1996169870644013 std: 0.8832914193087821
# Inverse of element average: 0.8335993994609173
# Average maximum row sum: 106.09844468466704 std: 6.979295202727662
# Average row sum: 37.18812659899644 std: 4.917958486420987
# Average minimum row sum: 23.34400530631188 std: 1.4342886030757647
# Average nearest neighbor distance: 0.31013325051529606 std: 0.02341467857327507
# Inverse of average nearest neighbor distance: 3.2244204655207684
# Average of inverse nearest neighbor distance: 3.243216550873041 std: 0.25069619118984915
# Average smallest distance in matrix: 0.11521677551143554 std: 0.04102523172003417
# ----------------------- Spectrum ------------------------
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 64 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.2008175497149722 std: 0.9050630913664871
# Inverse of element average: 0.8327659770107136
# Average maximum row sum: 201.4490280114959 std: 11.902736053366855
# Average row sum: 75.65150563204325 std: 7.183715581737164
# Average minimum row sum: 48.82856603874683 std: 2.00732877652249
# Average nearest neighbor distance: 0.24040660132036806 std: 0.0140391342781681
# Inverse of average nearest neighbor distance: 4.159619554986307
# Average of inverse nearest neighbor distance: 4.173937565753413 std: 0.2460067327688238
# Average smallest distance in matrix: 0.07294857090339465 std: 0.029331636679978478
# ----------------------- Spectrum ------------------------
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 80 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.2008457970690334 std: 0.8970444350194073
# Inverse of element average: 0.8327463879548497
# Average maximum row sum: 189.58044614131927 std: 11.207702394333557
# Average row sum: 94.86681796845363 std: 7.973105339423513
# Average minimum row sum: 65.1805114048731 std: 2.166384768230888
# Average nearest neighbor distance: 0.2215431370107598 std: 0.01031325550631402
# Inverse of average nearest neighbor distance: 4.513793627249362
# Average of inverse nearest neighbor distance: 4.523618215632008 std: 0.21141477444107723
# Average smallest distance in matrix: 0.06014309989947536 std: 0.02303991151582643
# ----------------------- Spectrum ------------------------
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 100 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.1985374338974832 std: 0.8830879508739765
# Inverse of element average: 0.8343502436533283
# Average maximum row sum: 246.5721047415194 std: 11.982408423874979
# Average row sum: 118.65520595585085 std: 8.786614169798346
# Average minimum row sum: 81.48750167271552 std: 2.431166330983352
# Average nearest neighbor distance: 0.2050828006576093 std: 0.009268350391296898
# Inverse of average nearest neighbor distance: 4.8760793045221
# Average of inverse nearest neighbor distance: 4.886129899348127 std: 0.222918916835178
# Average smallest distance in matrix: 0.05283755280094486 std: 0.01910479605738325
# ----------------------- Spectrum ------------------------
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 150 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.200362667557644 std: 0.9075548359060804
# Inverse of element average: 0.8330815569553506
# Average maximum row sum: 351.31339178150677 std: 16.630311630980703
# Average row sum: 178.85403746608895 std: 11.078118578815646
# Average minimum row sum: 124.4597494235698 std: 3.361798148186418
# Average nearest neighbor distance: 0.17683785371349572 std: 0.0063468537058610055
# Inverse of average nearest neighbor distance: 5.6548978569947606
# Average of inverse nearest neighbor distance: 5.662213579899355 std: 0.20408091389594096
# Average smallest distance in matrix: 0.03938659034975205 std: 0.015041985002008656
# ----------------------- Spectrum ------------------------
# --------------------- Simulation --------------------------
# Sampled matrices: 400 from MatrixInverseDistance
#   Dimension: 200 Distribution: uniform Correlated: True
#   Hard core distance: 0.001 Hard core count: 0.0
#   Parameter1: 1.0 Parameter2: 0.0
#   Exponent: -1 Logarithmic: False Logscale: (0.05,)
# ----------------------- Results ----------------------------
# Matrix element average: 1.1978741733589517 std: 0.8899125833706556
# Inverse of element average: 0.8348122217176668
# Average maximum row sum: 433.87869081983433 std: 17.549770580957066
# Average row sum: 238.3769604984314 std: 12.553761858592244
# Average minimum row sum: 174.4967655701357 std: 3.572767410858011
# Average nearest neighbor distance: 0.1606275649073232 std: 0.004892798138398587
# Inverse of average nearest neighbor distance: 6.225581521932223
# Average of inverse nearest neighbor distance: 6.231369450057948 std: 0.1901595500382348
# Average smallest distance in matrix: 0.033645463539831263 std: 0.011968149637610335
# ----------------------- Spectrum ------------------------

# %% [markdown]
# When does the asymptotic in N of the observables kick in. Typically when the dominant correction is 1/N.

# %%
# the asymptotic region
n_asym = 32
n_values_asym = n_values_np[n_values_np >= n_asym]

# %%
positive = []
positive_std = []
negative = []
negative_std = []
for S in simulations:
    positive.append(np.mean(S.positive)/S.Matrix.N)
    negative.append(np.mean(S.negative)/S.Matrix.N)
    positive_std.append(np.std(S.positive)/S.Matrix.N)
    negative_std.append(np.std(S.negative)/S.Matrix.N)
    print("N =", S.Matrix.N, "Positive %:", np.mean(S.positive)/S.Matrix.N, "std:", np.std(S.positive)/S.Matrix.N)
# Out:
# N = 2 Positive %: 0.5 std: 0.0
# N = 4 Positive %: 0.279375 std: 0.08050378484891255
# N = 8 Positive %: 0.2975 std: 0.06680194607943694
# N = 16 Positive %: 0.293125 std: 0.04045155281321102
# N = 32 Positive %: 0.279609375 std: 0.022744842950861963
# N = 64 Positive %: 0.275390625 std: 0.016120086157783868
# N = 80 Positive %: 0.27515625 std: 0.013932559382163062
# N = 100 Positive %: 0.2733 std: 0.013270644294833616
# N = 150 Positive %: 0.27168333333333333 std: 0.01051188480826451
# N = 200 Positive %: 0.2700375 std: 0.008947686502666485

# %% [markdown]
# Analysis of the signs of the eigenvalues:
#
# The ratio of negative and positive eigenvalues is plotted and compared with a situation where only the Perron eigenvalue is positive. This is true for distance matrices.

# %%
def one_over_n(n):
    return 1 / n if n != 0 else 0

only_perron = [1 - one_over_n(n) for n in n_values]

plt.figure(figsize=(10, 6))
plt.errorbar(n_values, positive, yerr=positive_std, label='Positive', marker='o')
plt.errorbar(n_values, negative, yerr=negative_std, label='Negative', marker='o')
plt.plot(n_values, only_perron, label='Only Perron', marker='o', linestyle='--')
plt.xlabel('Number of Targets (N)')
plt.ylabel('Fraction of Eigenvalues')
plt.title('Positive and Negative Eigenvalues for (' + distribution + ') vs Number of Targets')
plt.xticks(n_values)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.tight_layout()
if create_png:
    plt.savefig('positive_negative_samples_vs_n_' + distribution + '.png', dpi=300)
plt.show()

# %%
# use the last value as prediction as an input for the derivation of the 1/N correction
negative = np.array(negative)
prediction = negative[-1]
deviations = negative - prediction

# %% [markdown]
# A few extrapolation functions

# %%
# fitting functions for the assymptotic region
from scipy.optimize import curve_fit

# used for assymptotic region of the sign
def inv_func(x, a, b):
    return a / np.array(x) + b

# higher order terms for pf eigenvalues
def inv_func2(x, a, b, c):
    return a / x + b + c / x ** 2

# logarithmic correction terms
def inv_func_log(x, a, b, c):
    return a / np.array(x) + b + c / np.log(x)

# pure llogarithmic dependence
def log_func(x, a, b):
    return a / np.log(x) + b

# wigner distribution
def wigner(x, sigma):
    return (2 / (np.pi * sigma**2)) * np.sqrt(sigma**2 - x**2) * (np.abs(x) <= sigma)

# %%
# the n_values in the assymptotic region of the sign fit
deviations_signfit = deviations[n_values_np >= n_asym] 

params, covariance = curve_fit(inv_func, n_values_asym, deviations_signfit)
a_fit, b_fit = params

# %%
plt.figure(figsize=(10, 6))
plt.plot(n_values, deviations, 'o', label='Deviation Data')
x_fit = np.linspace(min(n_values_asym), max(n_values_asym), 200)
y_fit = a_fit / x_fit + b_fit
plt.plot(x_fit, y_fit, '-', label=f'Fitted Function: {a_fit:.2f}/x + {b_fit:.2f}')
plt.xlabel('Number of Targets (N)')
plt.ylabel('Deviation from Prediction')
plt.title('Deviation and Fitted Function Normal vs Number of Targets')
plt.xticks(n_values)
plt.ylim(-0.1, 0.01)
plt.grid()
plt.legend()
plt.tight_layout()
if create_png:
    plt.savefig('deviation_and_fit_vs_n_normal.png', dpi=300)
plt.show()

# %%
print("Initial prediction of ratio of negative values:", prediction)
print("Predicted assymptotic value of ratio of negative values:", b_fit + prediction)
print(" 1 / N correction:", a_fit)
print("Result: |S-| = ",  b_fit + prediction, " + 1 / N * ", a_fit)
print("Standard deviation of last value:", negative_std[-1])
# Out:
# Initial prediction of ratio of negative values: 0.7299625000000001
# Predicted assymptotic value of ratio of negative values: 0.7303876983097772
#  1 / N correction: -0.3393720082411479
# Result: |S-| =  0.7303876983097772  + 1 / N *  -0.3393720082411479
# Standard deviation of last value: 0.008947686502666485
